# %%
from PickliPy.Visualize import visualize_picklist

visualize_picklist(
    "C:\\Akos\\0Projects\\0Screen\\PickliPyTest\\6_AlphaLisa\\AlphaLISA_Picklist.csv",
    src_format="auto",      # or 96 / 384
    dst_format="auto",      # or 96 / 384
    color_scope="global",   # keeps source/destination colors matched
    dpi=300,
)
# Out:
# VisualizationResult(output_dir=WindowsPath('C:/Akos/0Projects/0Screen/PickliPyTest/6_AlphaLisa/AlphaLISA_Picklist_movement_viz'), destination_images={'X251105': WindowsPath('C:/Akos/0Projects/0Screen/PickliPyTest/6_AlphaLisa/AlphaLISA_Picklist_movement_viz/AlphaLISA_Picklist__destination__X251105.png')}, source_images={'PlateSRC': WindowsPath('C:/Akos/0Projects/0Screen/PickliPyTest/6_AlphaLisa/AlphaLISA_Picklist_movement_viz/AlphaLISA_Picklist__source__PlateSRC.png')}, event_count=342)

# %%
pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.2 MB 13.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.4/8.2 MB 8.8 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.2 MB 10.6 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.2 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.2 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 7.5 MB/s  0:00:01
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------- ----------------- 1.3/2.3 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 7.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/6 [pyparsing]
# ...
